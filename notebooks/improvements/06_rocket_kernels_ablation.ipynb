# %%
from pathlib import Path

nb_dir = Path.cwd()
project_root = nb_dir.parents  # AI4TS-ROCKET
results_dir = project_root / "experiments" / "results"
results_dir.mkdir(parents=True, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 nb_dir = Path.cwd()
#       4 project_root = nb_dir.parents  # AI4TS-ROCKET
# ----> 5 results_dir = project_root / "experiments" / "results"
#       6 results_dir.mkdir(parents=True, exist_ok=True)
#
# TypeError: unsupported operand type(s) for /: '_PathParents' and 'str'
