# %% [markdown]
# # Reproduce ROCKET on ElectricDevices

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Imports

# %%
import os
import sys
from pathlib import Path
import pandas as pd

nb_dir = Path.cwd()
PROJECT_ROOT = nb_dir.parents[1]
SRC_ROOT = PROJECT_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.append(str(SRC_ROOT))

from experiments_sktime import run_sktime_rocket_experiment

res = run_sktime_rocket_experiment("ElectricDevices", project_root=PROJECT_ROOT)
res
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# {'dataset': 'ElectricDevices',
#  'n_kernels': 10000,
#  'train_size': 8926,
#  'test_size': 7711,
#  'accuracy': 0.6673583192841396,
#  'fit_predict_time_sec': 111.48505902290344,
#  'total_time_sec': 112.1384699344635,
#  'random_state': 42,
#  'results_path': PosixPath('experiments/results/electricdevices_rocket_sktime.csv')}

# %%
df = pd.read_csv(PROJECT_ROOT / res["results_path"])
df
# Out:
#            dataset  n_kernels  train_size  test_size  accuracy  \
# 0  ElectricDevices      10000        8926       7711  0.667358
#
#    fit_predict_time_sec  total_time_sec  random_state
# 0            111.485059       112.13847            42
