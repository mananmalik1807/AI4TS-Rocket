# %% [markdown]
# # Reproduce ROCKET on GunPoint (sktime)
#
# This notebook calls the shared experiment code and displays the saved results.

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Imports

# %%
import os
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path(os.path.abspath(os.path.join(os.getcwd(), "..")))
SRC_ROOT = PROJECT_ROOT / "src"
if str(SRC_ROOT) not in sys.path:
    sys.path.append(str(SRC_ROOT))

from experiments_sktime import run_sktime_rocket_experiment

res = run_sktime_rocket_experiment("GunPoint", project_root=PROJECT_ROOT)
res
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# {'dataset': 'GunPoint',
#  'n_kernels': 10000,
#  'train_size': 50,
#  'test_size': 150,
#  'accuracy': 0.96,
#  'results_path': PosixPath('experiments/results/gunpoint_rocket_sktime.csv')}

# %%
df = pd.read_csv(PROJECT_ROOT / res["results_path"])
df
# Out:
#     dataset  n_kernels  train_size  test_size  accuracy
# 0  GunPoint      10000          50        150      0.96
